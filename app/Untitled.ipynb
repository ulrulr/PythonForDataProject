# %%
import pandas as pd

# %%
data = read.csv("biodeg_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-727a385744b3> in <module>
# ----> 1 data = read.csv("biodeg_cleaned.csv")
#
# NameError: name 'read' is not defined

# %%
# Out:
#                       0        1    2         3         4       5     6   \
# 0                SpMax_L  J_Dz(e)  nHM  F01[N-N]  F04[C-N]  NssssC  nCb-
# 1                  3.919   2.6909    0         0         0       0     0
# 2                   4.17   2.1144    0         0         0       0     0
# 3                  3.932   3.2512    0         0         0       0     0
# 4                    3.0   2.7098    0         0         0       0     0
# ...                  ...      ...  ...       ...       ...     ...   ...
# 1051               5.431   2.8955    0         0         0       2     0
# 1052   5.287000000000001   3.3732    0         0         9       0     0
# 1053               4.869    1.767    0         1         9       0     5
# 1054               5.158   1.6914    2         0        36       0     9
# 1055  5.0760000000000005   2.6588    2         0         0       0     4
#
#         7    8   9   ...     32        33     34                  35       36  \
# ...

# %%
data.iloc[:,:-1]
# Out:
#       SpMax_L  J_Dz(e)  nHM  F01[N-N]  F04[C-N]  NssssC  nCb-    C%  nCp  nO  \
# 0       3.919   2.6909    0         0         0       0     0  31.4    2   0
# 1       4.170   2.1144    0         0         0       0     0  30.8    1   1
# 2       3.932   3.2512    0         0         0       0     0  26.7    2   4
# 3       3.000   2.7098    0         0         0       0     0  20.0    0   2
# 4       4.236   3.3944    0         0         0       0     0  29.4    2   4
# ...       ...      ...  ...       ...       ...     ...   ...   ...  ...  ..
# 1050    5.431   2.8955    0         0         0       2     0  32.1    4   1
# 1051    5.287   3.3732    0         0         9       0     0  35.3    0   9
# 1052    4.869   1.7670    0         1         9       0     5  44.4    0   4
# 1053    5.158   1.6914    2         0        36       0     9  56.1    0   0
# 1054    5.076   2.6588    2         0         0       0     4  54.5    0   0
#
# ...
